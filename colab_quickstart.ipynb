# %% [markdown]
# # **AML Mistake Recognition**

# %% [markdown]
# # **1 Initial Setup**

# %% [markdown]
# ## 1.1 Install dependencies

# %%
# !pip install torcheval
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 179.2/179.2 kB 4.9 MB/s eta 0:00:00
# ...

# %% [markdown]
# ## 1.2 Import the project

# %%
## to delete /code if it already exists and you need to reclone the project
# !rm -r code
# Out:
# rm: cannot remove 'code': No such file or directory

# %%
# !git clone --recursive https://github.com/SimoneColu/AML_error_recognition.git code
# Out:
# Cloning into 'code'...
# remote: Enumerating objects: 487, done.
# remote: Counting objects: 100% (67/67), done.
# remote: Compressing objects: 100% (45/45), done.
# remote: Total 487 (delta 27), reused 56 (delta 21), pack-reused 420 (from 1)
# Receiving objects: 100% (487/487), 850.66 KiB | 2.19 MiB/s, done.
# Resolving deltas: 100% (309/309), done.
# Submodule 'annotations' (https://github.com/CaptainCook4D/annotations) registered for path 'annotations'
# Cloning into '/content/code/annotations'...
# remote: Enumerating objects: 152, done.
# remote: Counting objects: 100% (152/152), done.
# remote: Compressing objects: 100% (98/98), done.
# remote: Total 152 (delta 75), reused 108 (delta 46), pack-reused 0 (from 0)
# Receiving objects: 100% (152/152), 793.14 KiB | 9.67 MiB/s, done.
# Resolving deltas: 100% (75/75), done.
# Submodule path 'annotations': checked out '0e9a108be2cbcbcbd592e7418c0ab9c16232d27a'

# %% [markdown]
# ## 1.3 Mount the drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## 1.4 Set the constants

# %%
DRIVE_PATH = "/content/drive/MyDrive/AML_DAAI_25_26"
LOCAL_CODE_PATH = "/content/code"

## Creazione cartelle (il flag -p evita errori se esistono già)
# !mkdir -p {LOCAL_CODE_PATH}/data/video
# !mkdir -p {LOCAL_CODE_PATH}/checkpoints/error_recognition_best/MLP/omnivore
# !mkdir -p {LOCAL_CODE_PATH}/checkpoints/error_recognition_best/MLP/slowfast
# !mkdir -p {LOCAL_CODE_PATH}/checkpoints/error_recognition_best/Transformer/omnivore
# !mkdir -p {LOCAL_CODE_PATH}/checkpoints/error_recognition_best/Transformer/slowfast

# %% [markdown]
# # **2 Get the data and run**

# %% [markdown]
# ## **2.1 Omnivore**

# %%
# Estrazione features
# Usiamo -q (quiet) per non intasare l'output di Colab se il file è grande
# !unzip -q "{DRIVE_PATH}/data/backbone/omnivore.zip" -d {LOCAL_CODE_PATH}/data/video

# %% [markdown]
# ## 2.1.1 Omnivore - MLP - Step

# %%
# Copia del checkpoint
# !cp "{DRIVE_PATH}/data/checkpoint/MLP/error_recognition_MLP_omnivore_step_epoch_43.pt" {LOCAL_CODE_PATH}/checkpoints/error_recognition_best/MLP/omnivore/

# %%
# %%bash
#
# cd code
# python -m core.evaluate --variant MLP --backbone omnivore \
#   --ckpt checkpoints/error_recognition_best/MLP/omnivore/error_recognition_MLP_omnivore_step_epoch_43.pt \
#   --split step --threshold 0.6
# Out:
# Loaded annotations......
# Loading recording ids from recordings_combined_splits.json
#
# ===== TEST STRATIFIED SUB-STEP METRICS (vs Normal) =====
# Error Type 2.0: Recall=0.31, Precision=0.33 (Positives: 1211)
# Error Type 3.0: Recall=0.32, Precision=0.31 (Positives: 357)
# Error Type 4.0: Recall=0.32, Precision=0.34 (Positives: 1133)
# Error Type 5.0: Recall=0.31, Precision=0.34 (Positives: 1390)
# Error Type 6.0: Recall=0.32, Precision=0.33 (Positives: 848)
#
# ===== TEST STRATIFIED STEP METRICS (vs Normal) =====
# Error Type 2.0: Recall=0.18, Precision=0.62 (Positives: 33)
# Error Type 3.0: Recall=0.18, Precision=0.59 (Positives: 4)
# Error Type 4.0: Recall=0.17, Precision=0.60 (Positives: 26)
# Error Type 5.0: Recall=0.18, Precision=0.60 (Positives: 17)
# Error Type 6.0: Recall=0.18, Precision=0.61 (Positives: 27)
# ----------------------------------------------------------------
# ...

# %% [markdown]
# ## 2.1.2 Omnivore - MLP - Recordings -> NOT WORKING

# %%
# Copia del checkpoint
# !cp "{DRIVE_PATH}/data/checkpoint/MLP/error_recognition_MLP_omnivore_recordings_epoch_33.pt" {LOCAL_CODE_PATH}/checkpoints/error_recognition_best/MLP/omnivore/

# %%
# %%bash
#
# cd code
# python -m core.evaluate --variant MLP --backbone omnivore \
#   --ckpt checkpoints/error_recognition_best/MLP/omnivore/error_recognition_MLP_omnivore_recordings_epoch_33.pt \
#   --split recordings --threshold 0.6
# Out:
# Loaded annotations......
# Loading recording ids from recordings_combined_splits.json
#
# ===== TEST STRATIFIED SUB-STEP METRICS (vs Normal) =====
# Error Type 2.0: Recall=0.57, Precision=0.31 (Positives: 1305)
# Error Type 3.0: Recall=0.56, Precision=0.27 (Positives: 128)
# Error Type 4.0: Recall=0.58, Precision=0.33 (Positives: 2068)
# Error Type 5.0: Recall=0.55, Precision=0.30 (Positives: 1178)
# Error Type 6.0: Recall=0.55, Precision=0.28 (Positives: 793)
#
# ===== TEST STRATIFIED STEP METRICS (vs Normal) =====
# Error Type 2.0: Recall=0.24, Precision=0.41 (Positives: 24)
# Error Type 3.0: Recall=0.24, Precision=0.38 (Positives: 3)
# Error Type 4.0: Recall=0.25, Precision=0.44 (Positives: 35)
# Error Type 5.0: Recall=0.22, Precision=0.37 (Positives: 11)
# Error Type 6.0: Recall=0.23, Precision=0.40 (Positives: 26)
# ----------------------------------------------------------------
# ...

# %% [markdown]
# ## 2.1.3 Omnivore - Transformers - Step

# %%
# Checkpoint file name
CHECKPOINT_FILE_NAME = "error_recognition_Transformer_omnivore_step_epoch_9.pt"

# Copia del checkpoint
# !cp "{DRIVE_PATH}/data/checkpoint/Transformer/{CHECKPOINT_FILE_NAME}" {LOCAL_CODE_PATH}/checkpoints/error_recognition_best/Transformer/omnivore/

# %%
# %%bash
#
# cd code
# python -m core.evaluate --variant Transformer --backbone omnivore \
#   --ckpt checkpoints/error_recognition_best/Transformer/omnivore/error_recognition_Transformer_omnivore_step_epoch_9.pt \
#   --split step --threshold 0.6
# Out:
# Loaded annotations......
# Loading recording ids from recordings_combined_splits.json
#
# ===== TEST STRATIFIED SUB-STEP METRICS (vs Normal) =====
# Error Type 2.0: Recall=0.64, Precision=0.35 (Positives: 1211)
# Error Type 3.0: Recall=0.66, Precision=0.33 (Positives: 357)
# Error Type 4.0: Recall=0.67, Precision=0.35 (Positives: 1133)
# Error Type 5.0: Recall=0.66, Precision=0.36 (Positives: 1390)
# Error Type 6.0: Recall=0.62, Precision=0.33 (Positives: 848)
#
# ===== TEST STRATIFIED STEP METRICS (vs Normal) =====
# Error Type 2.0: Recall=0.60, Precision=0.43 (Positives: 33)
# Error Type 3.0: Recall=0.60, Precision=0.39 (Positives: 4)
# Error Type 4.0: Recall=0.62, Precision=0.43 (Positives: 26)
# Error Type 5.0: Recall=0.60, Precision=0.40 (Positives: 17)
# Error Type 6.0: Recall=0.57, Precision=0.41 (Positives: 27)
# ----------------------------------------------------------------
# ...

# %% [markdown]
# ## 2.1.4 Omnivore - Transformers - Recordings -> not working

# %%
# Checkpoint file name
CHECKPOINT_FILE_NAME = "error_recognition_Transformer_omnivore_recordings_epoch_31.pt"

# Copia del checkpoint
# !cp "{DRIVE_PATH}/data/checkpoint/Transformer/{CHECKPOINT_FILE_NAME}" {LOCAL_CODE_PATH}/checkpoints/error_recognition_best/Transformer/omnivore/

# %%
# %%bash
#
# cd code
# python -m core.evaluate --variant Transformer --backbone omnivore \
#   --ckpt checkpoints/error_recognition_best/Transformer/omnivore/error_recognition_Transformer_omnivore_recordings_epoch_31.pt \
#   --split recordings --threshold 0.6
# Out:
# Loaded annotations......
# Loading recording ids from recordings_combined_splits.json
#
# ===== TEST STRATIFIED SUB-STEP METRICS (vs Normal) =====
# Error Type 2.0: Recall=0.35, Precision=0.35 (Positives: 1305)
# Error Type 3.0: Recall=0.36, Precision=0.32 (Positives: 128)
# Error Type 4.0: Recall=0.37, Precision=0.39 (Positives: 2068)
# Error Type 5.0: Recall=0.35, Precision=0.35 (Positives: 1178)
# Error Type 6.0: Recall=0.36, Precision=0.35 (Positives: 793)
#
# ===== TEST STRATIFIED STEP METRICS (vs Normal) =====
# Error Type 2.0: Recall=0.29, Precision=0.36 (Positives: 24)
# Error Type 3.0: Recall=0.28, Precision=0.31 (Positives: 3)
# Error Type 4.0: Recall=0.31, Precision=0.39 (Positives: 35)
# Error Type 5.0: Recall=0.27, Precision=0.32 (Positives: 11)
# Error Type 6.0: Recall=0.30, Precision=0.36 (Positives: 26)
# ----------------------------------------------------------------
# ...

# %% [markdown]
# ## **2.2 Slowfast**

# %%
# Estrazione features
# Usiamo -q (quiet) per non intasare l'output di Colab se il file è grande
# !unzip -q "{DRIVE_PATH}/data/backbone/slowfast.zip" -d {LOCAL_CODE_PATH}/data/video

# %% [markdown]
# ## 2.2.1 Slowfast - MLP - Step

# %%
# Checkpoint file name
CHECKPOINT_FILE_NAME = "error_recognition_MLP_slowfast_step_epoch_15.pt"

# Copia del checkpoint
# !cp "{DRIVE_PATH}/data/checkpoint/MLP/{CHECKPOINT_FILE_NAME}" {LOCAL_CODE_PATH}/checkpoints/error_recognition_best/MLP/slowfast/

# %%
# %%bash
#
# cd code
# python -m core.evaluate --variant MLP --backbone slowfast \
#   --ckpt checkpoints/error_recognition_best/MLP/slowfast/error_recognition_MLP_slowfast_step_epoch_15.pt \
#   --split step --threshold 0.6
# Out:
# Loaded annotations......
# Loading recording ids from recordings_combined_splits.json
#
# ===== TEST STRATIFIED SUB-STEP METRICS (vs Normal) =====
# Error Type 2.0: Recall=0.04, Precision=0.31 (Positives: 1211)
# Error Type 3.0: Recall=0.04, Precision=0.29 (Positives: 357)
# Error Type 4.0: Recall=0.04, Precision=0.32 (Positives: 1133)
# Error Type 5.0: Recall=0.04, Precision=0.32 (Positives: 1390)
# Error Type 6.0: Recall=0.04, Precision=0.31 (Positives: 848)
#
# ===== TEST STRATIFIED STEP METRICS (vs Normal) =====
# Error Type 2.0: Recall=1.00, Precision=0.25 (Positives: 33)
# Error Type 3.0: Recall=1.00, Precision=0.22 (Positives: 4)
# Error Type 4.0: Recall=1.00, Precision=0.24 (Positives: 26)
# Error Type 5.0: Recall=1.00, Precision=0.23 (Positives: 17)
# Error Type 6.0: Recall=0.99, Precision=0.24 (Positives: 27)
# ----------------------------------------------------------------
# ...

# %% [markdown]
# ## 2.2.2 Slowfast - MLP - Recordings -> not working

# %%
# Checkpoint file name
CHECKPOINT_FILE_NAME = "error_recognition_MLP_slowfast_recordings_epoch_31.pt"

# Copia del checkpoint
# !cp "{DRIVE_PATH}/data/checkpoint/MLP/{CHECKPOINT_FILE_NAME}" {LOCAL_CODE_PATH}/checkpoints/error_recognition_best/MLP/slowfast/

# %%
# %%bash
#
# cd code
# python -m core.evaluate --variant MLP --backbone slowfast \
#   --ckpt checkpoints/error_recognition_best/MLP/slowfast/error_recognition_MLP_slowfast_recordings_epoch_31.pt \
#   --split recordings --threshold 0.6
# Out:
# Loaded annotations......
# Loading recording ids from recordings_combined_splits.json
#
# ===== TEST STRATIFIED SUB-STEP METRICS (vs Normal) =====
# Error Type 2.0: Recall=0.18, Precision=0.27 (Positives: 1305)
# Error Type 3.0: Recall=0.17, Precision=0.22 (Positives: 128)
# Error Type 4.0: Recall=0.17, Precision=0.28 (Positives: 2068)
# Error Type 5.0: Recall=0.15, Precision=0.24 (Positives: 1178)
# Error Type 6.0: Recall=0.17, Precision=0.24 (Positives: 793)
#
# ===== TEST STRATIFIED STEP METRICS (vs Normal) =====
# Error Type 2.0: Recall=0.06, Precision=0.24 (Positives: 24)
# Error Type 3.0: Recall=0.06, Precision=0.21 (Positives: 3)
# Error Type 4.0: Recall=0.05, Precision=0.21 (Positives: 35)
# Error Type 5.0: Recall=0.05, Precision=0.21 (Positives: 11)
# Error Type 6.0: Recall=0.07, Precision=0.26 (Positives: 26)
# ----------------------------------------------------------------
# ...

# %% [markdown]
# ## 2.2.3 Slowfast - Transformers - Step

# %%
# Checkpoint file name
CHECKPOINT_FILE_NAME = "error_recognition_Transformer_slowfast_step_epoch_25.pt"

# Copia del checkpoint
# !cp "{DRIVE_PATH}/data/checkpoint/Transformer/{CHECKPOINT_FILE_NAME}" {LOCAL_CODE_PATH}/checkpoints/error_recognition_best/MLP/slowfast/

# %%
# %%bash
#
# cd code
# python -m core.evaluate --variant Transformer --backbone slowfast \
#   --ckpt checkpoints/error_recognition_best/MLP/slowfast/error_recognition_Transformer_slowfast_step_epoch_25.pt \
#   --split step --threshold 0.6
# Out:
# Loaded annotations......
# Loading recording ids from recordings_combined_splits.json
#
# ===== TEST STRATIFIED SUB-STEP METRICS (vs Normal) =====
# Error Type 2.0: Recall=0.35, Precision=0.38 (Positives: 1211)
# Error Type 3.0: Recall=0.36, Precision=0.36 (Positives: 357)
# Error Type 4.0: Recall=0.38, Precision=0.39 (Positives: 1133)
# Error Type 5.0: Recall=0.34, Precision=0.37 (Positives: 1390)
# Error Type 6.0: Recall=0.38, Precision=0.38 (Positives: 848)
#
# ===== TEST STRATIFIED STEP METRICS (vs Normal) =====
# Error Type 2.0: Recall=0.25, Precision=0.39 (Positives: 33)
# Error Type 3.0: Recall=0.25, Precision=0.35 (Positives: 4)
# Error Type 4.0: Recall=0.27, Precision=0.40 (Positives: 26)
# Error Type 5.0: Recall=0.24, Precision=0.36 (Positives: 17)
# Error Type 6.0: Recall=0.25, Precision=0.39 (Positives: 27)
# ----------------------------------------------------------------
# ...

# %% [markdown]
# ## 2.2.4 Slowfast - Transformers - Recordings -> not working

# %%
# Checkpoint file name
CHECKPOINT_FILE_NAME = "error_recognition_Transformer_slowfast_recordings_epoch_49.pt"

# Copia del checkpoint
# !cp "{DRIVE_PATH}/data/checkpoint/Transformer/{CHECKPOINT_FILE_NAME}" {LOCAL_CODE_PATH}/checkpoints/error_recognition_best/MLP/slowfast/

# %%
# %%bash
#
# cd code
# python -m core.evaluate --variant Transformer --backbone slowfast \
#   --ckpt checkpoints/error_recognition_best/MLP/slowfast/error_recognition_Transformer_slowfast_step_epoch_25.pt \
#   --split recordings --threshold 0.6
# Out:
# Loaded annotations......
# Loading recording ids from recordings_combined_splits.json
#
# ===== TEST STRATIFIED SUB-STEP METRICS (vs Normal) =====
# Error Type 2.0: Recall=0.47, Precision=0.62 (Positives: 1305)
# Error Type 3.0: Recall=0.48, Precision=0.59 (Positives: 128)
# Error Type 4.0: Recall=0.49, Precision=0.65 (Positives: 2068)
# Error Type 5.0: Recall=0.43, Precision=0.59 (Positives: 1178)
# Error Type 6.0: Recall=0.49, Precision=0.62 (Positives: 793)
#
# ===== TEST STRATIFIED STEP METRICS (vs Normal) =====
# Error Type 2.0: Recall=0.41, Precision=0.58 (Positives: 24)
# Error Type 3.0: Recall=0.41, Precision=0.55 (Positives: 3)
# Error Type 4.0: Recall=0.43, Precision=0.60 (Positives: 35)
# Error Type 5.0: Recall=0.39, Precision=0.55 (Positives: 11)
# Error Type 6.0: Recall=0.42, Precision=0.59 (Positives: 26)
# ----------------------------------------------------------------
# ...
